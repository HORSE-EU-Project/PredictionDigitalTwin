# %%
# in upf_mec, run the following commands
#   $ tcpdump -i mec_host-s1 -w /open5gs/install/var/log/open5gs/pkt_mec_host-s1.pcap
#   $ tcpdump -i ogstun      -w /open5gs/install/var/log/open5gs/pkt_ogstun.pcap

from scapy.all import rdpcap
# import scapy.packet as packet

pkts_in  = rdpcap( "log/pkt_mec_host-s1.pcap"  )
pkts_out = rdpcap( "log/pkt_capture_ogstun.pcap" )

print( len(pkts_in) )
print( len(pkts_out) )

# pkts[47].show()
# cnt=0
for p in pkts_in:
    pkts_in[47].show()

#     print( "[" + str(cnt) + "] " +  str(p["TCP"].time) + " | " + p["IP"].src + " | " + p["IP"].dst + " | " + str(p["TCP"].flags) )
#     cnt = cnt + 1
#     # print(  p["TCP"].flags)
