# %%
######################################################
### SIMULATION
######################################################
import importlib, docker
import python_modules.UeRanSim
import python_modules.Open5GS
import python_modules.MonitorScenario
import python_modules.IperfApp
importlib.reload( python_modules.UeRanSim )
importlib.reload( python_modules.Open5GS )
importlib.reload( python_modules.MonitorScenario )
importlib.reload( python_modules.IperfApp )
from  python_modules.UeRanSim import UeRanSim
from  python_modules.Open5GS  import Open5GS
from  python_modules.MonitorScenario  import MonitorScenario
from  python_modules.IperfApp import IperfApp


d_client = docker.from_env()

d_client.containers.get("srv_mec")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File /usr/lib/python3/dist-packages/docker/api/client.py:261, in APIClient._raise_for_status(self, response)
#     260 try:
# --> 261     response.raise_for_status()
#     262 except requests.exceptions.HTTPError as e:
#
# File /usr/lib/python3/dist-packages/requests/models.py:940, in Response.raise_for_status(self)
#     939 if http_error_msg:
# --> 940     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: http+docker://localhost/v1.35/containers/srv_mec/json
#
# During handling of the above exception, another exception occurred:
#
# NotFound                                  Traceback (most recent call last)
# /home/vagrant/comnetsemu/app/5Gnet/Check_APPs.ipynb Cell 1 in <cell line: 21>()
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22436f6d6e657473656d75227d/home/vagrant/comnetsemu/app/5Gnet/Check_APPs.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=15'>16</a> from  python_modules.IperfApp import IperfApp
#      <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22436f6d6e657473656d75227d/home/vagrant/comnetsemu/app/5Gnet/Check_APPs.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=18'>19</a> d_client = docker.from_env()
# ---> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22436f6d6e657473656d75227d/home/vagrant/comnetsemu/app/5Gnet/Check_APPs.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=20'>21</a> d_client.containers.get("srv_mec")
#
# File /usr/lib/python3/dist-packages/docker/models/containers.py:880, in ContainerCollection.get(self, container_id)
#     864 def get(self, container_id):
#     865     """
#     866     Get a container by name or ID.
#     867
#    (...)
#     878             If the server returns an error.
#     879     """
# --> 880     resp = self.client.api.inspect_container(container_id)
#     881     return self.prepare_model(resp)
#
# File /usr/lib/python3/dist-packages/docker/utils/decorators.py:19, in check_resource.<locals>.decorator.<locals>.wrapped(self, resource_id, *args, **kwargs)
#      15 if not resource_id:
#      16     raise errors.NullResource(
#      17         'Resource ID was not provided'
#      18     )
# ---> 19 return f(self, resource_id, *args, **kwargs)
#
# File /usr/lib/python3/dist-packages/docker/api/container.py:757, in ContainerApiMixin.inspect_container(self, container)
#     741 @utils.check_resource('container')
#     742 def inspect_container(self, container):
#     743     """
#     744     Identical to the `docker inspect` command, but only for containers.
#     745
#    (...)
#     755             If the server returns an error.
#     756     """
# --> 757     return self._result(
#     758         self._get(self._url("/containers/{0}/json", container)), True
#     759     )
#
# File /usr/lib/python3/dist-packages/docker/api/client.py:267, in APIClient._result(self, response, json, binary)
#     265 def _result(self, response, json=False, binary=False):
#     266     assert not (json and binary)
# --> 267     self._raise_for_status(response)
#     269     if json:
#     270         return response.json()
#
# File /usr/lib/python3/dist-packages/docker/api/client.py:263, in APIClient._raise_for_status(self, response)
#     261     response.raise_for_status()
#     262 except requests.exceptions.HTTPError as e:
# --> 263     raise create_api_error_from_http_exception(e)
#
# File /usr/lib/python3/dist-packages/docker/errors.py:31, in create_api_error_from_http_exception(e)
#      29     else:
#      30         cls = NotFound
# ---> 31 raise cls(e, response=response, explanation=explanation)
#
# NotFound: 404 Client Error: Not Found ("No such container: srv_mec")
